# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Machine Learning/Introduction DS
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Machine Learning/Introduction DS

# %%
pip install currencyconverter
# Out:
# Collecting currencyconverter
#   Downloading https://files.pythonhosted.org/packages/f2/ec/b958817bba9a01bc3f286ffdf1501b3b98a44a11d368fa1e93eadbb87f20/CurrencyConverter-0.14.4.tar.gz (512kB)
#      |████████████████████████████████| 522kB 5.8MB/s
# Building wheels for collected packages: currencyconverter
#   Building wheel for currencyconverter (setup.py) ... done
#   Created wheel for currencyconverter: filename=CurrencyConverter-0.14.4-cp36-none-any.whl size=514210 sha256=8dac213529db0feb648e5ba8ac9e5206d4894a4fc734dce33d92fd3adbb47341
#   Stored in directory: /root/.cache/pip/wheels/49/d3/77/bf96356a8f75ce70320a6bcb5c751ac65210c1c1647393ebcd
# Successfully built currencyconverter
# Installing collected packages: currencyconverter
# Successfully installed currencyconverter-0.14.4

# %%
import numpy as np
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import keras
from keras import backend
from currency_converter import CurrencyConverter
sns.set()

# %%
data = read_csv('./data.csv', sep=',')
data.head(4)
# Out:
#                                 title  release  ... Western        budget
# 0                     Happiest Season     2020  ...       0           NaN
# 1  The Christmas Chronicles: Part Two     2020  ...       0           NaN
# 2                               Mulan     2020  ...       0  $200,000,000
# 3                          Home Alone     1990  ...       0   $18,000,000
#
# [4 rows x 39 columns]

# %% [markdown]
# ## **Xử lý dữ liệu**

# %%
gross = data.gross
for i in range(len(gross)):
  if not pd.isna(gross[i]):
    gross[i] = float(gross[i].replace(',',''))

c = CurrencyConverter()
budget = data.budget
for i in range(len(budget)):
  if not pd.isna(budget[i]):
    s = ''
    d = 'USD'
    for j in budget[i]:
      if j.isalpha():
        s += j
    n = re.findall(r'\d+', budget[i])
    n = ''.join(n)
    try:
      budget[i] = float(c.convert(int(n), s, d))
    except:
      budget[i] = float(n)
  
data = data[['title', 'certificate', 'director', 'star', 'genre', 'release', 'runtime', 'metascore', 'vote',
             'Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary',
 					  'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 
 					  'Musical', 'Mystery', 'News','Reality-TV',	'Romance', 'Sci-Fi', 'Sport', 'Talk-Show',	 
 					  'Thriller', 'War', 'Western','gross', 'budget', 'rating']]
data.head(4)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 title certificate  ...   budget rating
# 0                     Happiest Season       PG-13  ...      NaN    6.7
# 1  The Christmas Chronicles: Part Two          PG  ...      NaN    6.1
# 2                               Mulan       PG-13  ...    2e+08    5.5
# 3                          Home Alone          PG  ...  1.8e+07    7.6
#
# [4 rows x 38 columns]

# %%
print(data.release.min())
# Out:
# 1911

# %% [markdown]
# 1. Định dạng lại dữ liệu trong hai cột gross và budget: loại bỏ ký tự thừa, chuyển từ string thành float

# %% [markdown]
# 2. Thay thế các giá trị missing bằng giá trị trung bình

# %% [markdown]
# 3. Chuẩn hóa giá trị các biến numerical về khoảng [-1, 1]

# %% [markdown]
# 4. Chuyển đổi đơn vị tiền tệ sang một định dạng chung USD

# %% [markdown]
# 5. Chuyển thể loại phim sang one-hot encoding (26 thể loại)

# %% [markdown]
# ## **Phân tích dữ liệu**

# %%
len(data)
# Out:
# 30794

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30794 entries, 0 to 30793
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        30794 non-null  object
#  1   certificate  24818 non-null  object
#  2   director     30794 non-null  object
#  3   star         30786 non-null  object
#  4   genre        30794 non-null  object
#  5   release      30794 non-null  int64
#  6   runtime      30773 non-null  float64
#  7   metascore    12056 non-null  float64
#  8   vote         30794 non-null  int64
#  9   Action       30794 non-null  int64
#  10  Adventure    30794 non-null  int64
#  11  Animation    30794 non-null  int64
#  12  Biography    30794 non-null  int64
#  13  Comedy       30794 non-null  int64
#  14  Crime        30794 non-null  int64
#  15  Documentary  30794 non-null  int64
#  16  Drama        30794 non-null  int64
#  17  Family       30794 non-null  int64
#  18  Fantasy      30794 non-null  int64
#  19  Film-Noir    30794 non-null  int64
#  20  Game-Show    30794 non-null  int64
#  21  History      30794 non-null  int64
#  22  Horror       30794 non-null  int64
#  23  Music        30794 non-null  int64
#  24  Musical      30794 non-null  int64
#  25  Mystery      30794 non-null  int64
#  26  News         30794 non-null  int64
#  27  Reality-TV   30794 non-null  int64
#  28  Romance      30794 non-null  int64
#  29  Sci-Fi       30794 non-null  int64
#  30  Sport        30794 non-null  int64
#  31  Talk-Show    30794 non-null  int64
#  32  Thriller     30794 non-null  int64
#  33  War          30794 non-null  int64
#  34  Western      30794 non-null  int64
#  35  gross        12303 non-null  object
#  36  budget       13715 non-null  object
#  37  rating       30794 non-null  float64
# dtypes: float64(3), int64(28), object(7)
# memory usage: 8.9+ MB

# %%
data.describe()
# Out:
#             release       runtime  ...           War       Western
# count  30794.000000  30773.000000  ...  30794.000000  30794.000000
# mean    1996.300935    105.256816  ...      0.027765      0.015133
# std       22.056923     22.279307  ...      0.164302      0.122083
# min     1911.000000     25.000000  ...      0.000000      0.000000
# 25%     1986.000000     91.000000  ...      0.000000      0.000000
# 50%     2004.000000    100.000000  ...      0.000000      0.000000
# 75%     2013.000000    114.000000  ...      0.000000      0.000000
# max     2020.000000    729.000000  ...      1.000000      1.000000
#
# [8 rows x 31 columns]

# %%
data.isna().sum()
# Out:
# title              0
# release            0
# certificate     5976
# runtime           21
# genre              0
# rating             0
# metascore      18738
# summary           60
# director           0
# star               8
# vote               0
# gross          18491
# Action             0
# Adventure          0
# Animation          0
# Biography          0
# Comedy             0
# Crime              0
# Documentary        0
# Drama              0
# Family             0
# Fantasy            0
# Film-Noir          0
# Game-Show          0
# History            0
# Horror             0
# Music              0
# Musical            0
# Mystery            0
# News               0
# Reality-TV         0
# Romance            0
# Sci-Fi             0
# Sport              0
# Talk-Show          0
# Thriller           0
# War                0
# Western            0
# budget         17079
# dtype: int64

# %% [markdown]
# - Dữ liệu có 30794 bản ghi
# - Gồm có 13 trường dữ liệu: title, release, certificate, runtime, genre, metascore, summary, director, star, vote, gross, budget, rating
# - Các cột có giá trị NULL: certificate(5976), gross(18491), budget(17079), metascore(18738), summary(60), runtime(21)

# %% [markdown]
# **1. Rating**

# %%
plt.figure(figsize=(6,6))
sns.histplot(data.rating, kde=True)
#data.rating.plot.hist(figsize=(6,6))

# %% [markdown]
# Đa phần phim được đánh giá trong khoảng từ 5 đến 8

# %% [markdown]
# **2. Runtime**

# %%
plt.figure(figsize=(20,6))
sns.histplot(data[data.runtime<250].runtime, kde=True)

# %% [markdown]
# thời lượng phim tập trung trong khoảng 100 phút

# %% [markdown]
# **3. Year**

# %%
plt.figure(figsize=(20,6))
sns.histplot(data.release, kde=True)

# %% [markdown]
# số lượng phim tăng nhanh kể từ sau năm 1950 -> sau chiến tranh thế giới thứ 2 -> sự bất ổn chính trị và kinh tế ảnh hưởng đến sản xuất phim

# %% [markdown]
# **4. Vote**

# %%
plt.figure(figsize=(20,6))
sns.histplot(data[data.vote<20000].vote, kde=True)

# %% [markdown]
# right skewed -> người xem ít vote cho phim

# %% [markdown]
# **5. Gross**

# %%
plt.figure(figsize=(20,8))
sns.histplot(data[(data.gross.notnull()) & (data.gross < 60000000)].gross.astype('float64') , kde=True)

# %% [markdown]
# **6. Budget**

# %%
plt.figure(figsize=(20,6))
sns.histplot(data[(data.budget.notnull()) & (data.budget < 100000000)].budget.astype('float64') , kde=True)

# %% [markdown]
# Cả gross và budget đều tập trung trong khoảng 0-20 triệu đô, đồng thời hai biểu đồ có sự tương đồng cao -> sẽ đánh giá ở phần sau

# %% [markdown]
# **7. Genre**

# %%
plt.figure(figsize=(25, 6))
a = data[['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary',
 					  'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music', 
 					  'Musical', 'Mystery', 'News','Reality-TV',	'Romance', 'Sci-Fi', 'Sport', 'Talk-Show',	 
 					  'Thriller', 'War', 'Western']].sum().sort_values(ascending=False)
plt.xticks(rotation=40) 
sns.barplot(x=a.index, y=a.values)

# %% [markdown]
# Đa phần phim thuộc thể loại drama và comedy

# %% [markdown]
# **8. Metascore**

# %%
plt.figure(figsize=(6,6))
sns.histplot(data.metascore, kde=True)

# %% [markdown]
# Điểm metascore chủ yếu năm trong khoảng 50-70

# %% [markdown]
# **9. Sử dụng biến phụ thuộc là rating -> cần tìm mối quan hệ giữa các biến độc lập với rating**

# %% [markdown]
# 9.1. Độ tương quan giữa các cột

# %% [markdown]
# 9.1.1. Giữa các biến Numerical với rating

# %%
# runtime, gross, metascore, budget, vote, rating
plt.figure(figsize=(7,7))
df = data[['runtime', 'gross', 'metascore', 'budget', 'vote', 'release','rating']]
df = df.fillna(df.median())
sns.heatmap(df[df.columns].corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# rating có mối tương quan đáng kể với runtime, metascore, vote (tương quan dương) và release (tương quan âm)

# %% [markdown]
# 9.1.2. Giữa các biến Categorical với rating

# %%
# các thể loại phim và rating
plt.figure(figsize=(20, 20))
df = data[['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
					  'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror', 'Music', 
					  'Musical', 'Mystery',	'Romance', 'Sci-Fi', 'Sport',	 
					  'Thriller', 'War', 'Western', 'rating']]
sns.heatmap(df[df.columns].corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# rating có mối tương quan đáng kể với Drama (tương quan dương) và Horror (tương quan âm)

# %%
data_ = data.fillna(data.median())
run_max = data.runtime.max()
run_min = data.runtime.min()
run_mean = data.runtime.mean()

meta_max = data.metascore.max()
meta_min = data.metascore.min()
meta_mean = data.metascore.mean()

vote_max = data.vote.max()
vote_min = data.vote.min()
vote_mean = data.vote.mean()

gross_max = data.gross.max()
gross_min = data.gross.min()
gross_mean = data.gross.mean()

budget_max = data.budget.max()
budget_min = data.budget.min()
budget_mean = data.budget.mean()

data_.runtime = 2*(data_.runtime-run_mean)/(run_max-run_min)
data_.metascore = 2*(data_.metascore-meta_mean)/(meta_max-meta_min)
data_.vote = 2*(data_.vote-vote_mean)/(vote_max-vote_min)
data_.gross = 2*(data_.gross-gross_mean)/(gross_max-gross_min)
data_.budget = 2*(data_.budget-budget_mean)/(budget_max-budget_min)

data_.release = data.release - 1920
data_ = np.asarray(data_)

# %% [markdown]
# 9.2. Vote vs Rating

# %%
plt.figure(figsize=(15, 6))
sns.scatterplot(x=data.vote, y= data.rating)

# %% [markdown]
# Độ tương quan được thể hiện rõ: càng nhiều vote, rating càng cao, nhưng hầu hết những bộ phim không được nhiều người vote, rating có phương sai lớn

# %% [markdown]
# 9.3. Metascore vs Rating

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x=data.metascore, y= data.rating)

# %% [markdown]
# Metascore và rating có độ tương đồng lớn, metascore càng cao, rating càng cao

# %% [markdown]
# 9.4. Gross vs Rating

# %%
plt.figure(figsize=(15,15))
a = data[data.gross<4000000][['rating', 'gross']]
sns.jointplot(x=a.rating, y=a.gross)

# %% [markdown]
# Không có quan hệ tuyến tính giữa gross và rating -> do đó rating cao không tương quan với doanh thu của phim

# %% [markdown]
# 9.5. Budget vs Rating

# %%
plt.figure(figsize=(15,15))
a = data[data.budget<100000000][['rating', 'budget']]
sns.jointplot(x=a.rating, y=a.budget)

# %% [markdown]
# Không có quan hệ tuyến tính giữa budget và rating -> do đó kinh phí cao không tương quan với rating của phim

# %% [markdown]
# Cả gross và budget đều không có mối quan hệ tuyến tính với rating, đông thời hai trường dữ liệu này có nhiều giá trị mising, gross và budget còn phụ thuộc vào nhiều yếu tố khách quan khác như lạm phát, khấu hao, ... -> không dùng hai trường này trong mô hình

# %% [markdown]
# 9.6. Runtime vs Rating

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x=data.runtime, y= data.rating)

# %% [markdown]
# Ở đây cũng chỉ ra thời lượng phim dài tương đồng với rating cao, nhưng chỉ có một số rất ít phim có thời lượng lớn

# %% [markdown]
# 9.7. Release vs Rating

# %%
plt.figure(figsize=(20, 6))
plt.scatter(data.release, data.rating)
plt.xlabel('year')
plt.ylabel('rating')
# Out:
# Text(0, 0.5, 'rating')

# %% [markdown]
# rating và year có tương quan âm, do càng gần đây, phương sai của rating càng lớn -> có nhiều phim bị đánh giá tiêu cực

# %% [markdown]
# # **Xây dựng mô hình**

# %% [markdown]
# Từ những phân tích trên, ta chọn các biến sau cho mô hình: runtime, metascore, vote, release, drama và horror

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30794 entries, 0 to 30793
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        30794 non-null  object
#  1   certificate  24818 non-null  object
#  2   director     30794 non-null  object
#  3   star         30786 non-null  object
#  4   genre        30794 non-null  object
#  5   release      30794 non-null  int64
#  6   runtime      30773 non-null  float64
#  7   metascore    12056 non-null  float64
#  8   vote         30794 non-null  int64
#  9   Action       30794 non-null  int64
#  10  Adventure    30794 non-null  int64
#  11  Animation    30794 non-null  int64
#  12  Biography    30794 non-null  int64
#  13  Comedy       30794 non-null  int64
#  14  Crime        30794 non-null  int64
#  15  Documentary  30794 non-null  int64
#  16  Drama        30794 non-null  int64
#  17  Family       30794 non-null  int64
#  18  Fantasy      30794 non-null  int64
#  19  Film-Noir    30794 non-null  int64
#  20  Game-Show    30794 non-null  int64
#  21  History      30794 non-null  int64
#  22  Horror       30794 non-null  int64
#  23  Music        30794 non-null  int64
#  24  Musical      30794 non-null  int64
#  25  Mystery      30794 non-null  int64
#  26  News         30794 non-null  int64
#  27  Reality-TV   30794 non-null  int64
#  28  Romance      30794 non-null  int64
#  29  Sci-Fi       30794 non-null  int64
#  30  Sport        30794 non-null  int64
#  31  Talk-Show    30794 non-null  int64
#  32  Thriller     30794 non-null  int64
#  33  War          30794 non-null  int64
#  34  Western      30794 non-null  int64
#  35  gross        12303 non-null  object
#  36  budget       13715 non-null  object
#  37  rating       30794 non-null  float64
# dtypes: float64(3), int64(28), object(7)
# memory usage: 8.9+ MB

# %%
data_[:, 5]
# Out:
# array([100, 100, 100, ..., 69, 100, 100], dtype=object)

# %% [markdown]
# **1. Hồi quy**

# %%
train_data, test_data = train_test_split(data_, test_size=0.2, random_state=1)
train_data, val_data = train_test_split(train_data, test_size= 0.1, random_state=1)

# %%
X_train, y_train = train_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), train_data[:,-1].astype(np.float32)
X_test, y_test = test_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), test_data[:,-1].astype(np.float32)
X_val, y_val = val_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), val_data[:, -1].astype(np.float32)

# X_train, y_train = train_data[:, 5:35].astype(np.float32), train_data[:,-1].astype(np.float32)
# X_test, y_test = test_data[:, 5:35].astype(np.float32), test_data[:,-1].astype(np.float32)
# X_val, y_val = val_data[:, 5:35].astype(np.float32), val_data[:, -1].astype(np.float32)

# %% [markdown]
# - Linear Regression

# %%
LR = LinearRegression()
LR.fit(X_train, y_train)
w = LR.coef_
b = LR.intercept_
print('W: ', w)
print('b: ', b)
#print('Score: ', LR.score(X_train, y_train)) # Score Coefficient of determination -->  càng lớn càng tốt

# RMSE
y_pred = LR.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('RMSE (Linear Regression): ', rmse)
# Out:
# W:  [-0.01278728  3.4435582   1.1768237   2.4857302  -0.1748898  -0.20872873
#   0.7588389   0.12817201  0.37402147 -0.596463   -0.3942163 ]
# b:  7.2172394
# RMSE (Linear Regression):  0.8813454

# %% [markdown]
# - Ridge Regression

# %%
# i = 0.01
# while i<30:
ridge = Ridge(alpha=5)
ridge.fit(X_train, y_train)
w = ridge.coef_
b = ridge.intercept_
print('W: ', w)
print('b: ', b)
#print('Score: ', ridge.score(X_train, y_train))


y_pred = ridge.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('RMSE (Ridge Regression): ', rmse)

  #print('Ridge RMSE: {}, {:.4f}'.format(i, rmse))
  # i += 0.1
# Out:
# W:  [-0.01269879  3.2517822   1.1835996   2.405391   -0.16950737 -0.20403174
#   0.7429719   0.13357252  0.37774444 -0.6011515  -0.39251658]
# b:  7.207545
# RMSE (Ridge Regression):  0.8813942

# %% [markdown]
# - Lasso Regression

# %%
# i = 0.01
# while i<10:
print(len(X_train[0]))
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
w = lasso.coef_
b = lasso.intercept_
print('W: ', w)
print('b: ', b)
#print('Score: ', lasso.score(X_train, y_train))

y_pred = lasso.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('RMSE (Lasso Regression): ', rmse)

  # print('Lasso RMSE {}, {:.4f}'.format(i,rmse))
  # i+=0.01
# Out:
# 30
# W:  [-1.1323555e-02  9.9819654e-01  1.2139020e+00  8.3347940e-01
#  -6.7425214e-02 -1.9432357e-04  2.4039380e-01  4.4815559e-03
#  -0.0000000e+00  0.0000000e+00  0.0000000e+00  4.2792815e-01
#  -0.0000000e+00 -0.0000000e+00  0.0000000e+00  0.0000000e+00
#   0.0000000e+00 -6.0971266e-01  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00 -0.0000000e+00
#  -2.2448565e-01  0.0000000e+00  0.0000000e+00 -0.0000000e+00
#   0.0000000e+00 -0.0000000e+00]
# b:  7.044532
# RMSE (Lasso Regression):  0.9076762

# %%
plt.figure(figsize=(20, 6))
plt.plot(np.linspace(0, 10), np.linspace(0, 10))
plt.scatter(y_pred, y_test, alpha=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9e63408b48a4> in <module>()
#       1 plt.figure(figsize=(20, 6))
#       2 plt.plot(np.linspace(0, 10), np.linspace(0, 10))
# ----> 3 plt.scatter(y_pred, y_test, alpha=0.2)
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# **2. Neural network**

# %%
# X_train, y_train = train_data[:, 5:35].astype(np.float32), train_data[:,-1].astype(np.float32)
# X_test, y_test = test_data[:, 5:35].astype(np.float32), test_data[:,-1].astype(np.float32)
# X_val, y_val = val_data[:, 5:35].astype(np.float32), val_data[:, -1].astype(np.float32)

X_train, y_train = train_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), train_data[:,-1].astype(np.float32)
X_test, y_test = test_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), test_data[:,-1].astype(np.float32)
X_val, y_val = val_data[:, [5,6,7,8,9,10,11,12,16,22,29]].astype(np.float32), val_data[:, -1].astype(np.float32)

# %%
model = Sequential()
model.add(Dense(100, input_shape=(11,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(50))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 100)               1200
# _________________________________________________________________
# activation_8 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 50)                200
# _________________________________________________________________
# activation_9 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 7,491
# Trainable params: 7,391
# Non-trainable params: 100
# _________________________________________________________________

# %%
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss=rmse,
              optimizer=opt,
              metrics=[rmse])

# %%
epoch = 100
batch_size = 32

filepath="model_Proj_.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_rmse', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

H = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=batch_size, epochs=epoch, verbose=1, callbacks=callbacks_list)

N = np.arange(0, epoch)
plt.style.use("ggplot")
plt.figure(figsize=(10, 6))
plt.plot(N, H.history["loss"])
plt.plot(N, H.history["val_loss"])
#plt.title("Loss and RMSE")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["train_loss","val_loss"], loc="upper right")
plt.show()
# Out:
# Epoch 1/100
# 693/693 [==============================] - 2s 2ms/step - loss: 2.1327 - rmse: 2.1327 - val_loss: 3.6679 - val_rmse: 3.6679
#
# Epoch 00001: val_rmse improved from inf to 3.66794, saving model to model_Proj_.hdf5
# Epoch 2/100
# 693/693 [==============================] - 1s 2ms/step - loss: 1.2189 - rmse: 1.2189 - val_loss: 2.6274 - val_rmse: 2.6274
#
# Epoch 00002: val_rmse improved from 3.66794 to 2.62737, saving model to model_Proj_.hdf5
# Epoch 3/100
# 693/693 [==============================] - 1s 2ms/step - loss: 1.0966 - rmse: 1.0966 - val_loss: 2.2086 - val_rmse: 2.2086
#
# Epoch 00003: val_rmse improved from 2.62737 to 2.20860, saving model to model_Proj_.hdf5
# Epoch 4/100
# 693/693 [==============================] - 1s 2ms/step - loss: 1.0153 - rmse: 1.0153 - val_loss: 1.7611 - val_rmse: 1.7611
#
# Epoch 00004: val_rmse improved from 2.20860 to 1.76105, saving model to model_Proj_.hdf5
# Epoch 5/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.9828 - rmse: 0.9828 - val_loss: 1.5813 - val_rmse: 1.5813
#
# Epoch 00005: val_rmse improved from 1.76105 to 1.58130, saving model to model_Proj_.hdf5
# Epoch 6/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.9495 - rmse: 0.9495 - val_loss: 1.1389 - val_rmse: 1.1389
#
# Epoch 00006: val_rmse improved from 1.58130 to 1.13887, saving model to model_Proj_.hdf5
# Epoch 7/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.9203 - rmse: 0.9203 - val_loss: 0.9481 - val_rmse: 0.9481
#
# Epoch 00007: val_rmse improved from 1.13887 to 0.94812, saving model to model_Proj_.hdf5
# Epoch 8/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.8893 - rmse: 0.8893 - val_loss: 0.9254 - val_rmse: 0.9254
#
# Epoch 00008: val_rmse improved from 0.94812 to 0.92538, saving model to model_Proj_.hdf5
# Epoch 9/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.8794 - rmse: 0.8794 - val_loss: 0.8348 - val_rmse: 0.8348
#
# Epoch 00009: val_rmse improved from 0.92538 to 0.83481, saving model to model_Proj_.hdf5
# Epoch 10/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.8386 - rmse: 0.8386 - val_loss: 0.8631 - val_rmse: 0.8631
#
# Epoch 00010: val_rmse did not improve from 0.83481
# Epoch 11/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.8212 - rmse: 0.8212 - val_loss: 0.7106 - val_rmse: 0.7106
#
# Epoch 00011: val_rmse improved from 0.83481 to 0.71058, saving model to model_Proj_.hdf5
# Epoch 12/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.8059 - rmse: 0.8059 - val_loss: 0.7831 - val_rmse: 0.7831
#
# Epoch 00012: val_rmse did not improve from 0.71058
# Epoch 13/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7933 - rmse: 0.7933 - val_loss: 0.7147 - val_rmse: 0.7147
#
# Epoch 00013: val_rmse did not improve from 0.71058
# Epoch 14/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7765 - rmse: 0.7765 - val_loss: 0.6962 - val_rmse: 0.6962
#
# Epoch 00014: val_rmse improved from 0.71058 to 0.69624, saving model to model_Proj_.hdf5
# Epoch 15/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7659 - rmse: 0.7659 - val_loss: 0.6762 - val_rmse: 0.6762
#
# Epoch 00015: val_rmse improved from 0.69624 to 0.67616, saving model to model_Proj_.hdf5
# Epoch 16/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7665 - rmse: 0.7665 - val_loss: 0.6865 - val_rmse: 0.6865
#
# Epoch 00016: val_rmse did not improve from 0.67616
# Epoch 17/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7384 - rmse: 0.7384 - val_loss: 0.6872 - val_rmse: 0.6872
#
# Epoch 00017: val_rmse did not improve from 0.67616
# Epoch 18/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7350 - rmse: 0.7350 - val_loss: 0.6734 - val_rmse: 0.6734
#
# Epoch 00018: val_rmse improved from 0.67616 to 0.67341, saving model to model_Proj_.hdf5
# Epoch 19/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7249 - rmse: 0.7249 - val_loss: 0.6846 - val_rmse: 0.6846
#
# Epoch 00019: val_rmse did not improve from 0.67341
# Epoch 20/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7270 - rmse: 0.7270 - val_loss: 0.6690 - val_rmse: 0.6690
#
# Epoch 00020: val_rmse improved from 0.67341 to 0.66902, saving model to model_Proj_.hdf5
# Epoch 21/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7233 - rmse: 0.7233 - val_loss: 0.6604 - val_rmse: 0.6604
#
# Epoch 00021: val_rmse improved from 0.66902 to 0.66044, saving model to model_Proj_.hdf5
# Epoch 22/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7090 - rmse: 0.7090 - val_loss: 0.6642 - val_rmse: 0.6642
#
# Epoch 00022: val_rmse did not improve from 0.66044
# Epoch 23/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6974 - rmse: 0.6974 - val_loss: 0.6708 - val_rmse: 0.6708
#
# Epoch 00023: val_rmse did not improve from 0.66044
# Epoch 24/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.7006 - rmse: 0.7006 - val_loss: 0.6676 - val_rmse: 0.6676
#
# Epoch 00024: val_rmse did not improve from 0.66044
# Epoch 25/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6905 - rmse: 0.6905 - val_loss: 0.6652 - val_rmse: 0.6652
#
# Epoch 00025: val_rmse did not improve from 0.66044
# Epoch 26/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6850 - rmse: 0.6850 - val_loss: 0.6566 - val_rmse: 0.6566
#
# Epoch 00026: val_rmse improved from 0.66044 to 0.65656, saving model to model_Proj_.hdf5
# Epoch 27/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6851 - rmse: 0.6851 - val_loss: 0.6570 - val_rmse: 0.6570
#
# Epoch 00027: val_rmse did not improve from 0.65656
# Epoch 28/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6707 - rmse: 0.6707 - val_loss: 0.6573 - val_rmse: 0.6573
#
# Epoch 00028: val_rmse did not improve from 0.65656
# Epoch 29/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6816 - rmse: 0.6816 - val_loss: 0.6581 - val_rmse: 0.6581
#
# Epoch 00029: val_rmse did not improve from 0.65656
# Epoch 30/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6801 - rmse: 0.6801 - val_loss: 0.6742 - val_rmse: 0.6742
#
# Epoch 00030: val_rmse did not improve from 0.65656
# Epoch 31/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6766 - rmse: 0.6766 - val_loss: 0.6573 - val_rmse: 0.6573
#
# Epoch 00031: val_rmse did not improve from 0.65656
# Epoch 32/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6719 - rmse: 0.6719 - val_loss: 0.6587 - val_rmse: 0.6587
#
# Epoch 00032: val_rmse did not improve from 0.65656
# Epoch 33/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6655 - rmse: 0.6655 - val_loss: 0.6631 - val_rmse: 0.6631
#
# Epoch 00033: val_rmse did not improve from 0.65656
# Epoch 34/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6700 - rmse: 0.6700 - val_loss: 0.6575 - val_rmse: 0.6575
#
# Epoch 00034: val_rmse did not improve from 0.65656
# Epoch 35/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6589 - rmse: 0.6589 - val_loss: 0.6630 - val_rmse: 0.6630
#
# Epoch 00035: val_rmse did not improve from 0.65656
# Epoch 36/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6671 - rmse: 0.6671 - val_loss: 0.6578 - val_rmse: 0.6578
#
# Epoch 00036: val_rmse did not improve from 0.65656
# Epoch 37/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6630 - rmse: 0.6630 - val_loss: 0.6598 - val_rmse: 0.6598
#
# Epoch 00037: val_rmse did not improve from 0.65656
# Epoch 38/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6689 - rmse: 0.6689 - val_loss: 0.6619 - val_rmse: 0.6619
#
# Epoch 00038: val_rmse did not improve from 0.65656
# Epoch 39/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6639 - rmse: 0.6639 - val_loss: 0.6652 - val_rmse: 0.6652
#
# Epoch 00039: val_rmse did not improve from 0.65656
# Epoch 40/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6564 - rmse: 0.6564 - val_loss: 0.6594 - val_rmse: 0.6594
#
# Epoch 00040: val_rmse did not improve from 0.65656
# Epoch 41/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6553 - rmse: 0.6553 - val_loss: 0.6597 - val_rmse: 0.6597
#
# Epoch 00041: val_rmse did not improve from 0.65656
# Epoch 42/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6571 - rmse: 0.6571 - val_loss: 0.6559 - val_rmse: 0.6559
#
# Epoch 00042: val_rmse improved from 0.65656 to 0.65587, saving model to model_Proj_.hdf5
# Epoch 43/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6569 - rmse: 0.6569 - val_loss: 0.6646 - val_rmse: 0.6646
#
# Epoch 00043: val_rmse did not improve from 0.65587
# Epoch 44/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6677 - rmse: 0.6677 - val_loss: 0.6549 - val_rmse: 0.6549
#
# Epoch 00044: val_rmse improved from 0.65587 to 0.65491, saving model to model_Proj_.hdf5
# Epoch 45/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6598 - rmse: 0.6598 - val_loss: 0.6600 - val_rmse: 0.6600
#
# Epoch 00045: val_rmse did not improve from 0.65491
# Epoch 46/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6605 - rmse: 0.6605 - val_loss: 0.6596 - val_rmse: 0.6596
#
# Epoch 00046: val_rmse did not improve from 0.65491
# Epoch 47/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6538 - rmse: 0.6538 - val_loss: 0.6552 - val_rmse: 0.6552
#
# Epoch 00047: val_rmse did not improve from 0.65491
# Epoch 48/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6563 - rmse: 0.6563 - val_loss: 0.6546 - val_rmse: 0.6546
#
# Epoch 00048: val_rmse improved from 0.65491 to 0.65456, saving model to model_Proj_.hdf5
# Epoch 49/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6450 - rmse: 0.6450 - val_loss: 0.6643 - val_rmse: 0.6643
#
# Epoch 00049: val_rmse did not improve from 0.65456
# Epoch 50/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6556 - rmse: 0.6556 - val_loss: 0.6541 - val_rmse: 0.6541
#
# Epoch 00050: val_rmse improved from 0.65456 to 0.65405, saving model to model_Proj_.hdf5
# Epoch 51/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6581 - rmse: 0.6581 - val_loss: 0.6574 - val_rmse: 0.6574
#
# Epoch 00051: val_rmse did not improve from 0.65405
# Epoch 52/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6606 - rmse: 0.6606 - val_loss: 0.6745 - val_rmse: 0.6745
#
# Epoch 00052: val_rmse did not improve from 0.65405
# Epoch 53/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6581 - rmse: 0.6581 - val_loss: 0.6566 - val_rmse: 0.6566
#
# Epoch 00053: val_rmse did not improve from 0.65405
# Epoch 54/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6561 - rmse: 0.6561 - val_loss: 0.6541 - val_rmse: 0.6541
#
# Epoch 00054: val_rmse did not improve from 0.65405
# Epoch 55/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6570 - rmse: 0.6570 - val_loss: 0.6582 - val_rmse: 0.6582
#
# Epoch 00055: val_rmse did not improve from 0.65405
# Epoch 56/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6523 - rmse: 0.6523 - val_loss: 0.6623 - val_rmse: 0.6623
#
# Epoch 00056: val_rmse did not improve from 0.65405
# Epoch 57/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6494 - rmse: 0.6494 - val_loss: 0.6552 - val_rmse: 0.6552
#
# Epoch 00057: val_rmse did not improve from 0.65405
# Epoch 58/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6453 - rmse: 0.6453 - val_loss: 0.6590 - val_rmse: 0.6590
#
# Epoch 00058: val_rmse did not improve from 0.65405
# Epoch 59/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6599 - rmse: 0.6599 - val_loss: 0.6565 - val_rmse: 0.6565
#
# Epoch 00059: val_rmse did not improve from 0.65405
# Epoch 60/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6541 - rmse: 0.6541 - val_loss: 0.6585 - val_rmse: 0.6585
#
# Epoch 00060: val_rmse did not improve from 0.65405
# Epoch 61/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6449 - rmse: 0.6449 - val_loss: 0.6653 - val_rmse: 0.6653
#
# Epoch 00061: val_rmse did not improve from 0.65405
# Epoch 62/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6480 - rmse: 0.6480 - val_loss: 0.6712 - val_rmse: 0.6712
#
# Epoch 00062: val_rmse did not improve from 0.65405
# Epoch 63/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6545 - rmse: 0.6545 - val_loss: 0.6571 - val_rmse: 0.6571
#
# Epoch 00063: val_rmse did not improve from 0.65405
# Epoch 64/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6425 - rmse: 0.6425 - val_loss: 0.6600 - val_rmse: 0.6600
#
# Epoch 00064: val_rmse did not improve from 0.65405
# Epoch 65/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6461 - rmse: 0.6461 - val_loss: 0.6598 - val_rmse: 0.6598
#
# Epoch 00065: val_rmse did not improve from 0.65405
# Epoch 66/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6521 - rmse: 0.6521 - val_loss: 0.6536 - val_rmse: 0.6536
#
# Epoch 00066: val_rmse improved from 0.65405 to 0.65357, saving model to model_Proj_.hdf5
# Epoch 67/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6528 - rmse: 0.6528 - val_loss: 0.6568 - val_rmse: 0.6568
#
# Epoch 00067: val_rmse did not improve from 0.65357
# Epoch 68/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6500 - rmse: 0.6500 - val_loss: 0.6646 - val_rmse: 0.6646
#
# Epoch 00068: val_rmse did not improve from 0.65357
# Epoch 69/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6580 - rmse: 0.6580 - val_loss: 0.6691 - val_rmse: 0.6691
#
# Epoch 00069: val_rmse did not improve from 0.65357
# Epoch 70/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6458 - rmse: 0.6458 - val_loss: 0.6512 - val_rmse: 0.6512
#
# Epoch 00070: val_rmse improved from 0.65357 to 0.65125, saving model to model_Proj_.hdf5
# Epoch 71/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6504 - rmse: 0.6504 - val_loss: 0.6550 - val_rmse: 0.6550
#
# Epoch 00071: val_rmse did not improve from 0.65125
# Epoch 72/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6391 - rmse: 0.6391 - val_loss: 0.6570 - val_rmse: 0.6570
#
# Epoch 00072: val_rmse did not improve from 0.65125
# Epoch 73/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6440 - rmse: 0.6440 - val_loss: 0.6577 - val_rmse: 0.6577
#
# Epoch 00073: val_rmse did not improve from 0.65125
# Epoch 74/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6466 - rmse: 0.6466 - val_loss: 0.6654 - val_rmse: 0.6654
#
# Epoch 00074: val_rmse did not improve from 0.65125
# Epoch 75/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6510 - rmse: 0.6510 - val_loss: 0.6567 - val_rmse: 0.6567
#
# Epoch 00075: val_rmse did not improve from 0.65125
# Epoch 76/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6494 - rmse: 0.6494 - val_loss: 0.6568 - val_rmse: 0.6568
#
# Epoch 00076: val_rmse did not improve from 0.65125
# Epoch 77/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6543 - rmse: 0.6543 - val_loss: 0.6597 - val_rmse: 0.6597
#
# Epoch 00077: val_rmse did not improve from 0.65125
# Epoch 78/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6475 - rmse: 0.6475 - val_loss: 0.6687 - val_rmse: 0.6687
#
# Epoch 00078: val_rmse did not improve from 0.65125
# Epoch 79/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6400 - rmse: 0.6400 - val_loss: 0.6614 - val_rmse: 0.6614
#
# Epoch 00079: val_rmse did not improve from 0.65125
# Epoch 80/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6440 - rmse: 0.6440 - val_loss: 0.6660 - val_rmse: 0.6660
#
# Epoch 00080: val_rmse did not improve from 0.65125
# Epoch 81/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6447 - rmse: 0.6447 - val_loss: 0.6663 - val_rmse: 0.6663
#
# Epoch 00081: val_rmse did not improve from 0.65125
# Epoch 82/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6386 - rmse: 0.6386 - val_loss: 0.6675 - val_rmse: 0.6675
#
# Epoch 00082: val_rmse did not improve from 0.65125
# Epoch 83/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6462 - rmse: 0.6462 - val_loss: 0.6600 - val_rmse: 0.6600
#
# Epoch 00083: val_rmse did not improve from 0.65125
# Epoch 84/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6438 - rmse: 0.6438 - val_loss: 0.6616 - val_rmse: 0.6616
#
# Epoch 00084: val_rmse did not improve from 0.65125
# Epoch 85/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6445 - rmse: 0.6445 - val_loss: 0.6570 - val_rmse: 0.6570
#
# Epoch 00085: val_rmse did not improve from 0.65125
# Epoch 86/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6429 - rmse: 0.6429 - val_loss: 0.6810 - val_rmse: 0.6810
#
# Epoch 00086: val_rmse did not improve from 0.65125
# Epoch 87/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6425 - rmse: 0.6425 - val_loss: 0.6674 - val_rmse: 0.6674
#
# Epoch 00087: val_rmse did not improve from 0.65125
# Epoch 88/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6558 - rmse: 0.6558 - val_loss: 0.6570 - val_rmse: 0.6570
#
# Epoch 00088: val_rmse did not improve from 0.65125
# Epoch 89/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6485 - rmse: 0.6485 - val_loss: 0.6526 - val_rmse: 0.6526
#
# Epoch 00089: val_rmse did not improve from 0.65125
# Epoch 90/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6450 - rmse: 0.6450 - val_loss: 0.6562 - val_rmse: 0.6562
#
# Epoch 00090: val_rmse did not improve from 0.65125
# Epoch 91/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6404 - rmse: 0.6404 - val_loss: 0.6547 - val_rmse: 0.6547
#
# Epoch 00091: val_rmse did not improve from 0.65125
# Epoch 92/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6511 - rmse: 0.6511 - val_loss: 0.6526 - val_rmse: 0.6526
#
# Epoch 00092: val_rmse did not improve from 0.65125
# Epoch 93/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6401 - rmse: 0.6401 - val_loss: 0.6650 - val_rmse: 0.6650
#
# Epoch 00093: val_rmse did not improve from 0.65125
# Epoch 94/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6442 - rmse: 0.6442 - val_loss: 0.6526 - val_rmse: 0.6526
#
# Epoch 00094: val_rmse did not improve from 0.65125
# Epoch 95/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6334 - rmse: 0.6334 - val_loss: 0.6615 - val_rmse: 0.6615
#
# Epoch 00095: val_rmse did not improve from 0.65125
# Epoch 96/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6422 - rmse: 0.6422 - val_loss: 0.6719 - val_rmse: 0.6719
#
# Epoch 00096: val_rmse did not improve from 0.65125
# Epoch 97/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6450 - rmse: 0.6450 - val_loss: 0.6574 - val_rmse: 0.6574
#
# Epoch 00097: val_rmse did not improve from 0.65125
# Epoch 98/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6333 - rmse: 0.6333 - val_loss: 0.6566 - val_rmse: 0.6566
#
# Epoch 00098: val_rmse did not improve from 0.65125
# Epoch 99/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6412 - rmse: 0.6412 - val_loss: 0.6682 - val_rmse: 0.6682
#
# Epoch 00099: val_rmse did not improve from 0.65125
# Epoch 100/100
# 693/693 [==============================] - 1s 2ms/step - loss: 0.6368 - rmse: 0.6368 - val_loss: 0.6607 - val_rmse: 0.6607
#
# Epoch 00100: val_rmse did not improve from 0.65125

# %%
model.evaluate(X_test, y_test)
# Out:
# 193/193 [==============================] - 0s 1ms/step - loss: 0.6253 - rmse: 0.6253
# [0.6252871751785278, 0.6252871751785278]

# %%
#model = load_model('model_Proj_.hdf5', compile=False)
y_pred = model.predict(X_test)

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(rmse)
# Out:
# 0.8695073

# %% [markdown]
# # **Nhận xét**

# %% [markdown]
# Với mô hình hồi quy tuyến tính, trung bình mỗi rating bị dự đoán sai lệch khoảng 0.8993065
#
# Với mô hình mạng neural, trung bình mỗi rating bị dự đoán sai lệch khoảng 0.8668821
